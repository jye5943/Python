# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize

url = 'http://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=Mzg4M2JhYWQ2NTRhYzNmNTFlZDI1MzdjYzlkODcwMjg=&format=json&jsonVD=Y&userStatsId=kinatic/101/DT_1OH0503/2/1/20190418172421&prdSe=Y&newEstPrdCnt=1'

response = requests.get(url)

json = response.json()

df = json_normalize(json)

# %%
df
# Out:
#     C1    C1_NM          C1_NM_ENG C1_OBJ_NM  C2                C2_NM  \
# 0   00       전국      Whole country    주택소재지별  00                   총계
# 1   00       전국      Whole country    주택소재지별  01       동일시군구 거주자 소유주택
# 2   00       전국      Whole country    주택소재지별  02  동일시도내 타시군구 거주자 소유주택
# 3   00       전국      Whole country    주택소재지별  03         타시도 거주자 소유주택
# 4   11    서울특별시              Seoul    주택소재지별  00                   총계
# 5   11    서울특별시              Seoul    주택소재지별  01       동일시군구 거주자 소유주택
# 6   11    서울특별시              Seoul    주택소재지별  02  동일시도내 타시군구 거주자 소유주택
# 7   11    서울특별시              Seoul    주택소재지별  03         타시도 거주자 소유주택
# 8   21    부산광역시              Busan    주택소재지별  00                   총계
# 9   21    부산광역시              Busan    주택소재지별  01       동일시군구 거주자 소유주택
# 10  21    부산광역시              Busan    주택소재지별  02  동일시도내 타시군구 거주자 소유주택
# 11  21    부산광역시              Busan    주택소재지별  03         타시도 거주자 소유주택
# ...

# %%
df.to_csv('./주택소재지별 소유자의 거주지역별 주택수 현황(관내인 및 외지인 소유).csv', encoding='ms949')
