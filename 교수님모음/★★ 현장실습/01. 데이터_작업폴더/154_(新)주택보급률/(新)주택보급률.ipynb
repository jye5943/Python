# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize

url = 'http://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=Mzg4M2JhYWQ2NTRhYzNmNTFlZDI1MzdjYzlkODcwMjg=&format=json&jsonVD=Y&userStatsId=kinatic/116/DT_MLTM_2100/2/1/20190418165547&prdSe=Y&newEstPrdCnt=1'

response = requests.get(url)

json = response.json()

df = json_normalize(json)

# %%
df
# Out:
#                  C1 C1_NM          C1_NM_ENG C1_OBJ_NM   C1_OBJ_NM_ENG  \
# 0   13102871096A.01    전국      Whole country        구분  Classification
# 1   13102871096A.01    전국      Whole country        구분  Classification
# 2   13102871096A.01    전국      Whole country        구분  Classification
# 3   13102871096A.02   수도권       Capital Area        구분  Classification
# 4   13102871096A.02   수도권       Capital Area        구분  Classification
# 5   13102871096A.02   수도권       Capital Area        구분  Classification
# 6   13102871096A.03    서울              Seoul        구분  Classification
# 7   13102871096A.03    서울              Seoul        구분  Classification
# 8   13102871096A.03    서울              Seoul        구분  Classification
# 9   13102871096A.04    지방       Other Region        구분  Classification
# 10  13102871096A.04    지방       Other Region        구분  Classification
# 11  13102871096A.04    지방       Other Region        구분  Classification
# ...

# %%
df.to_csv('./(新)주택보급률.csv', encoding='ms949')
