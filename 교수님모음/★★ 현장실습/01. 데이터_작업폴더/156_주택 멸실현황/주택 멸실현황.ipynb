# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize

url = 'http://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=Mzg4M2JhYWQ2NTRhYzNmNTFlZDI1MzdjYzlkODcwMjg=&format=json&jsonVD=Y&userStatsId=kinatic/116/DT_MLTM_5416/2/1/20190418171726&prdSe=Y&newEstPrdCnt=1'

response = requests.get(url)

json = response.json()

df = json_normalize(json)

# %%
df
# Out:
#                   C1 C1_NM C1_OBJ_NM   C1_OBJ_NM_ENG      DT         ITM_ID  \
# 0    13102883384A.01    전국        구분  Classification  117730  13103883384T1
# 1    13102883384A.01    전국        구분  Classification   52323  13103883384T2
# 2    13102883384A.01    전국        구분  Classification   26723  13103883384T3
# 3    13102883384A.01    전국        구분  Classification    5017  13103883384T4
# 4    13102883384A.01    전국        구분  Classification    8159  13103883384T5
# 5    13102883384A.01    전국        구분  Classification   25508  13103883384T6
# 6    13102883384A.02   수도권        구분  Classification   69808  13103883384T1
# 7    13102883384A.02   수도권        구분  Classification   18354  13103883384T2
# 8    13102883384A.02   수도권        구분  Classification   19026  13103883384T3
# 9    13102883384A.02   수도권        구분  Classification    4107  13103883384T4
# 10   13102883384A.02   수도권        구분  Classification    6901  13103883384T5
# ...

# %%
df.to_csv('./주택 멸실현황.csv', encoding='ms949')
