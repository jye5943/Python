# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize

url = 'http://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=Mzg4M2JhYWQ2NTRhYzNmNTFlZDI1MzdjYzlkODcwMjg=&format=json&jsonVD=Y&userStatsId=kinatic/116/DT_MLTM_592/2/1/20190418171342&prdSe=Y&newEstPrdCnt=1'

response = requests.get(url)

json = response.json()

df = json_normalize(json)

# %%
df
# Out:
#                  C1 C1_NM      C1_NM_ENG C1_OBJ_NM   C1_OBJ_NM_ENG       DT  \
# 0   13102766977A.01    전국  Whole Country        구분  Classification  13535.4
# 1   13102766977A.01    전국  Whole Country        구분  Classification  15988.8
# 2   13102766977A.01    전국  Whole Country        구분  Classification    118.1
# 3   13102766977A.02   수도권   Capital Area        구분  Classification   6721.6
# 4   13102766977A.02   수도권   Capital Area        구분  Classification   7223.7
# 5   13102766977A.02   수도권   Capital Area        구분  Classification    107.5
# 6   13102766977A.03    서울          Seoul        구분  Classification   2635.8
# 7   13102766977A.03    서울          Seoul        구분  Classification   2736.1
# 8   13102766977A.03    서울          Seoul        구분  Classification    103.8
# 9   13102766977A.04    지방          Local        구분  Classification   6813.9
# 10  13102766977A.04    지방          Local        구분  Classification   8765.1
# ...

# %%
df.to_csv('./(종전)주택보급률.csv', encoding='ms949')
