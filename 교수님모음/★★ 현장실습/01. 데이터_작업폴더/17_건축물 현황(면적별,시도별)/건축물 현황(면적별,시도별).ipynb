# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize

# %%
url='http://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=ZmY2Yzg3OTY1ODQ3Y2FlMDE4MDVkZTMyN2MxM2ZjMjA=&format=json&jsonVD=Y&userStatsId=botopia/116/TX_116110033/2/1/20190418174023&prdSe=Y&newEstPrdCnt=1'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
json = response.json()

# %%
df = json_normalize(json)
df.head()
# Out:
#                      C1 C1_NM C1_NM_ENG C1_OBJ_NM  \
# 0  1511613102251771A.00     계     Total       시도별
# 1  1511613102251771A.00     계     Total       시도별
# 2  1511613102251771A.00     계     Total       시도별
# 3  1511613102251771A.00     계     Total       시도별
# 4  1511613102251771A.00     계     Total       시도별
#
#                     C1_OBJ_NM_ENG                   C2  C2_NM C2_NM_ENG  \
# 0  Metropolitan city and province  1511613102251771B.0      계     Total
# 1  Metropolitan city and province  1511613102251771B.2    주거용       NaN
# 2  Metropolitan city and province  1511613102251771B.3    상업용       NaN
# 3  Metropolitan city and province  1511613102251771B.4    공업용       NaN
# 4  Metropolitan city and province  1511613102251771B.5  문교사회용       NaN
#
#   C2_OBJ_NM       DT              ITM_ID ITM_NM ORG_ID PRD_DE PRD_SE  \
# 0       용도별  6460489  1611613103251771T2     동수    116   2007      A
# 1       용도별  4364730  1611613103251771T2     동수    116   2007      A
# ...

# %%
df.to_csv("./건축물 현황(시도별,용도별).csv")
