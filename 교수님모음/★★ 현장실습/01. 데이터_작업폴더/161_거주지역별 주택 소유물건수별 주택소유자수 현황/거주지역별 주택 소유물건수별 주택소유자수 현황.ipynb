# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize

url = 'http://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=Mzg4M2JhYWQ2NTRhYzNmNTFlZDI1MzdjYzlkODcwMjg=&format=json&jsonVD=Y&userStatsId=kinatic/101/DT_1OH0506/2/1/20190418174518&prdSe=Y&newEstPrdCnt=1'

response = requests.get(url)

json = response.json()

df = json_normalize(json)

# %%
df
# Out:
#     C1    C1_NM          C1_NM_ENG C1_OBJ_NM   C2  C2_NM C2_OBJ_NM        DT  \
# 0   00       전국      Whole country     거주지역별  000     총계    소유물건수별  13669851
# 1   00       전국      Whole country     거주지역별  010     1건    소유물건수별  11550688
# 2   00       전국      Whole country     거주지역별  020     2건    소유물건수별   1659681
# 3   00       전국      Whole country     거주지역별  030  3건 이상    소유물건수별    459482
# 4   11    서울특별시              Seoul     거주지역별  000     총계    소유물건수별   2436182
# 5   11    서울특별시              Seoul     거주지역별  010     1건    소유물건수별   2047176
# 6   11    서울특별시              Seoul     거주지역별  020     2건    소유물건수별    289171
# 7   11    서울특별시              Seoul     거주지역별  030  3건 이상    소유물건수별     99835
# 8   21    부산광역시              Busan     거주지역별  000     총계    소유물건수별    973593
# 9   21    부산광역시              Busan     거주지역별  010     1건    소유물건수별    823956
# 10  21    부산광역시              Busan     거주지역별  020     2건    소유물건수별    114390
# ...

# %%
df.to_csv('./거주지역별 주택 소유물건수별 주택소유자수 현황.csv', encoding='ms949')
