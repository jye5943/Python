# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize

url = 'http://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=Mzg4M2JhYWQ2NTRhYzNmNTFlZDI1MzdjYzlkODcwMjg=&format=json&jsonVD=Y&userStatsId=kinatic/101/DT_1OH0504/2/1/20190418172616&prdSe=Y&newEstPrdCnt=1'

response = requests.get(url)

json = response.json()

df = json_normalize(json)

# %%
df
# Out:
#      C1    C1_NM         C1_NM_ENG C1_OBJ_NM C2 C2_NM C2_OBJ_NM   C3   C3_NM  \
# 0    00       전국     Whole country     거주지역별  0    총계        성별  000      총계
# 1    00       전국     Whole country     거주지역별  0    총계        성별  100   30세미만
# 2    00       전국     Whole country     거주지역별  0    총계        성별  200  30~39세
# 3    00       전국     Whole country     거주지역별  0    총계        성별  300  40~49세
# 4    00       전국     Whole country     거주지역별  0    총계        성별  400  50~59세
# 5    00       전국     Whole country     거주지역별  0    총계        성별  500  60~69세
# 6    00       전국     Whole country     거주지역별  0    총계        성별  600  70~79세
# 7    00       전국     Whole country     거주지역별  0    총계        성별  700   80세이상
# 8    00       전국     Whole country     거주지역별  0    총계        성별  800     사망자
# 9    00       전국     Whole country     거주지역별  1    남자        성별  000      총계
# 10   00       전국     Whole country     거주지역별  1    남자        성별  100   30세미만
# ...

# %%
df.to_csv('./거주지역별 성별 연령대별 주택소유자수 현황.csv', encoding='ms949')
