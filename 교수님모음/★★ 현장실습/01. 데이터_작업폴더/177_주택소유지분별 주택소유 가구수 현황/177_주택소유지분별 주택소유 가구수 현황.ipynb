# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize

# %%
url = 'http://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=NmE2ZTYwYzZjNzUxNjdiZjRiOTkxNDI4MWQ4MzhmYWQ=&format=json&jsonVD=Y&userStatsId=akwkhh/101/DT_1OH0408/2/1/20190418175019&prdSe=Y&newEstPrdCnt=1'
response = requests.get(url)
response
json = response.json()
df = json_normalize(json)
df.head()
# Out:
#     C1      C1_NM C1_OBJ_NM        DT ITM_ID ITM_NM ORG_ID PRD_DE PRD_SE  \
# 0  000         총계  주택 소유지분별  11000007   T001  일반가구수    101   2017      A
# 1  010       1호이하  주택 소유지분별   8038349   T001  일반가구수    101   2017      A
# 2  020  1호초과~2호이하  주택 소유지분별   2202298   T001  일반가구수    101   2017      A
# 3  030  2호초과~3호이하  주택 소유지분별    499920   T001  일반가구수    101   2017      A
# 4  040  3호초과~4호이하  주택 소유지분별    132267   T001  일반가구수    101   2017      A
#
#        TBL_ID               TBL_NM UNIT_NM UNIT_NM_ENG
# 0  DT_1OH0408  주택소유지분별 주택소유 가구수 현황      가구  Households
# 1  DT_1OH0408  주택소유지분별 주택소유 가구수 현황      가구  Households
# 2  DT_1OH0408  주택소유지분별 주택소유 가구수 현황      가구  Households
# 3  DT_1OH0408  주택소유지분별 주택소유 가구수 현황      가구  Households
# 4  DT_1OH0408  주택소유지분별 주택소유 가구수 현황      가구  Households

# %%
df.to_csv("./177_주택소유지분별 주택소유 가구수 현황.csv" , encoding= "ms949")
