# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize

url = 'http://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=Mzg4M2JhYWQ2NTRhYzNmNTFlZDI1MzdjYzlkODcwMjg=&format=json&jsonVD=Y&userStatsId=kinatic/101/DT_1OH0501/2/1/20190418172051&prdSe=Y&newEstPrdCnt=1'

response = requests.get(url)

json = response.json()

df = json_normalize(json)

# %%
df
# Out:
#     C1    C1_NM          C1_NM_ENG C1_OBJ_NM        DT ITM_ID   ITM_NM ORG_ID  \
# 0   00       전국      Whole country    주택소유지별  17122573   T001      총주택    101
# 1   00       전국      Whole country    주택소유지별  14963975   T002   개인소유주택    101
# 2   00       전국      Whole country    주택소유지별  10375363   T003     총아파트    101
# 3   00       전국      Whole country    주택소유지별   8697344   T004  개인소유아파트    101
# 4   11    서울특별시              Seoul    주택소유지별   2866845   T001      총주택    101
# 5   11    서울특별시              Seoul    주택소유지별   2552576   T002   개인소유주택    101
# 6   11    서울특별시              Seoul    주택소유지별   1665922   T003     총아파트    101
# 7   11    서울특별시              Seoul    주택소유지별   1409694   T004  개인소유아파트    101
# 8   21    부산광역시              Busan    주택소유지별   1200422   T001      총주택    101
# 9   21    부산광역시              Busan    주택소유지별   1090217   T002   개인소유주택    101
# 10  21    부산광역시              Busan    주택소유지별    776079   T003     총아파트    101
# ...

# %%
df.to_csv('./주택소재지별 주택수 현황(개인단위).csv', encoding='ms949')
