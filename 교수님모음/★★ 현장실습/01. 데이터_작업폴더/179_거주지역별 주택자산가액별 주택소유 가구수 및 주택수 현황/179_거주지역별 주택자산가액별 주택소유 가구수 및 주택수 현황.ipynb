# %%
import pandas as pd
import requests
from pandas.io.json import json_normalize

# %%
url = 'http://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=NmE2ZTYwYzZjNzUxNjdiZjRiOTkxNDI4MWQ4MzhmYWQ=&format=json&jsonVD=Y&userStatsId=akwkhh/101/DT_1OH0410/2/1/20190418180645&prdSe=Y&newEstPrdCnt=1'
response = requests.get(url)
response
json = response.json()
df = json_normalize(json)
df.head()
# Out:
#    C1 C1_NM      C1_NM_ENG C1_OBJ_NM   C2     C2_NM C2_OBJ_NM  C3    C3_NM  \
# 0  00    전국  Whole country     거주지역별  000        총계  주택자산 가액별  01  주택소유 가구
# 1  00    전국  Whole country     거주지역별  000        총계  주택자산 가액별  02  가구소유 주택
# 2  00    전국  Whole country     거주지역별  010    0.6억이하  주택자산 가액별  01  주택소유 가구
# 3  00    전국  Whole country     거주지역별  010    0.6억이하  주택자산 가액별  02  가구소유 주택
# 4  00    전국  Whole country     거주지역별  020  0.6~1.5억  주택자산 가액별  01  주택소유 가구
#
#   C3_OBJ_NM        DT ITM_ID           ITM_NM ORG_ID PRD_DE PRD_SE  \
# 0  주택소유 현황별  11000007   T001  일반 가구수 및 소유 주택수    101   2017      A
# 1  주택소유 현황별  14973014   T001  일반 가구수 및 소유 주택수    101   2017      A
# 2  주택소유 현황별   1740974   T001  일반 가구수 및 소유 주택수    101   2017      A
# 3  주택소유 현황별   1724981   T001  일반 가구수 및 소유 주택수    101   2017      A
# 4  주택소유 현황별   3390716   T001  일반 가구수 및 소유 주택수    101   2017      A
#
#        TBL_ID                           TBL_NM UNIT_NM
# 0  DT_1OH0410  거주지역별 주택자산가액별 주택소유 가구수 및 주택수 현황    가구/호
# ...

# %%
df.to_csv("./179_거주지역별 주택자산가액별 주택소유 가구수 및 주택수 현황.csv", encoding = "ms949")
