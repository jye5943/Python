# %% [markdown]
# ## 01. Import

# %%
import os
import requests #Used to service API connection
from lxml import html #Used to parse XML
from bs4 import BeautifulSoup #Used to read XML table on webpage
import pandas as pd
from pandas.io.json import json_normalize
import wget
import math

# %% [markdown]
# ## 02. 함수 정의

# %% [markdown]
# #### 　　　　　02-1. URL 생성 함수

# %%
def makeURL(myUrl, op, myKey, sigunguCd, bjdongCd):
    # myUrl = "http://192.168.1.120/index.php?"
    url = myUrl + '/'+ op + "?ServiceKey=" + myKey + "&sigunguCd=" + sigunguCd + '&bjdongCd=' + bjdongCd
    url = url.rstrip('&')
    return url

# %% [markdown]
# #### 　　　　　02-2. 폴더 생성 함수

# %%
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

# %% [markdown]
# #### 　　　　　02-2-2. inbound 생성

# %%
def autoDownSource(url):
    outPath = '../data/inbound/'
    filename = url.split('/')[-1].replace('.csv', '')
    createFolder(outPath)
    wget.download(url, outPath)

# %% [markdown]
# #### 　　　　　02-3. xml 데이터 추출 함수 ( 우리가 뽑아낼 데이터는 xml이기때문에 xml빼고는 삭제함)

# %%
def xmlProcess(url):
    response = requests.get(url)
    # Check if page is up
    if response.status_code == 200:
        # Convert webpage to %Data
        Data = BeautifulSoup(response.text, 'lxml-xml')
        result = []
        rows = 0
        columnName = []
        # search Item all item tag
        iterData = Data.find_all('item')
        for item in iterData:
            item_list = []
            # Fill the value in one row
            for tag in item.find_all():
                try:
                    tagname = tag.name
                    if rows == 0:
                        columnName.append(tagname)
                    item_list.append(item.find(tagname).text)
                except Exception as e:
                    print("This row will be ignored. ", item_list)
            if len(item_list) == 0:
                return pd.DataFrame()
            rows = rows + 1
            result.append(item_list)

    finalResult = pd.DataFrame(result)
    finalResult.columns = columnName

    return finalResult

# %% [markdown]
# ## 03. 데이터 추출 및 정제

# %% [markdown]
# #### 　　　　　03-1. Google docs의 데이터를 받아오기

# %%
dataList = pd.read_csv("https://docs.google.com/spreadsheets/d/1VngqG-m7G8k1587c21MZoheR1Fz3amp1mJtiBvA1Jb0/export?format=csv&gid=0")

# dataList라는 변수안에 받아온 데이터를 저장 ( Google docs의 '사이트'칼럼의 길이를 출력한다 )
print("### The total number of target data is " + str(len(dataList)))
# Out:
# ### The total number of target data is 425

# %%
dataList = dataList[   dataList['사이트'].notnull() ]

# dataList라는 변수안에 받아온 '사이트'칼럼의 데이터가 null값이라면 저장하지않고 null값이 아니라면 저장한다 
# ( 최종적으로 '사이트'칼럼에 데이터가 있는 부분만 저장이 되어 출력 )
print(dataList[["사이트"]])
print("### The total number of filtered data is " + str(len(dataList)))

# dataList라는 변수에 null값들을 빈 문자열을 넣어 채워주고 인덱스를 초기화 해준다.
dataList = dataList.fillna("") 
dataList = dataList.reset_index(drop=True)
# Out:
#                                                    사이트
# 305  https://www.data.go.kr/dataset/fileDownload.do...
# 306  http://openapi.kab.co.kr/OpenAPI_ToolInstallPa...
# 307  http://apis.data.go.kr/1611000/nsdi/LandCharac...
# 308  http://apis.data.go.kr/1611000/nsdi/LandCharac...
# 309  http://apis.data.go.kr/1611000/nsdi/BuildingAg...
# 310  http://apis.data.go.kr/1611000/nsdi/BuildingAg...
# 311  http://apis.data.go.kr/1611000/nsdi/Fluctuatio...
# 312  http://apis.data.go.kr/1611000/nsdi/Fluctuatio...
# 313  http://apis.data.go.kr/1611000/nsdi/Fluctuatio...
# 314  http://apis.data.go.kr/1611000/nsdi/BuildingUs...
# 315  http://apis.data.go.kr/1611000/nsdi/BuildingUs...
# 316  http://apis.data.go.kr/1611000/nsdi/Fluctuatio...
# 321         https://data.myhome.go.kr/rentalHouseList?
# 326  http://openapi.kab.co.kr/OpenAPI_ToolInstallPa...
# 327  http://openapi.kab.co.kr/OpenAPI_ToolInstallPa...
# 348      http://apis.data.go.kr/1611000/ArchPmsService
# 350        http://fsc.go.kr/downManager?bbsid=BBS0069&
# 353  http://apis.data.go.kr/1611000/ArchPmsService/...
# 357  http://data.insight.go.kr/openapi/service/Pric...
# 360  http://openapi.molit.go.kr/OpenAPI_ToolInstall...
# 361  http://openapi.kab.co.kr/OpenAPI_ToolInstallPa...
# 362  http://openapi.kab.co.kr/OpenAPI_ToolInstallPa...
# 363  https://www.data.go.kr/dataset/fileDownload.do...
# 367  http://openapi.kab.co.kr/OpenAPI_ToolInstallPa...
# 368  http://api.hf.go.kr:8090/service/rest/HfMbsInt...
# 369  http://api.hf.go.kr:8090/service/rest/HfMbbInt...
# 371  https://www.data.go.kr/dataset/fileDownload.do...
# 384  https://www.data.go.kr/dataset/fileDownload.do...
# 385  http://api.hf.go.kr:8090/service/rest/uloanrat...
# 386  https://www.data.go.kr/dataset/fileDownload.do...
# 387  http://api.hf.go.kr:8090/service/rest/conforml...
# ### The total number of filtered data is 31

# %% [markdown]
# #### 　　　　　03-2. Google docs에서 지정된 이름으로 폴더를 생성

# %%
outPath = "../data/outbound/"

# folderList라는 변수 안에 Google docs에서 받아온 '폴더명'칼럼의 데이터를 List형태로 저장함
folderList = dataList["폴더명"].tolist()

# folderList의 길이만큼 for문을 돌면서 폴더를 생성
for i in folderList:
    createFolder(outPath+i)

# %% [markdown]
# #### 　　　　　03-3. 데이터 정제에 필요한 정보들을 변수화 하여 입력

# %%
inputUrl = 'http://apis.data.go.kr/1611000/ArchPmsService'
inputKey = "ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D"
inputFolder = "340_건축인허가 정보"
inputFile = "getApBasisOulnInfo&getApDongOulnInfo&getApFlrOulnInfo&getApHoOulnInfo&getApImprprInfo&getApHdcrMgmRgstInfo&getApDemolExtngMgmRgstInfo&getApTmpBldInfo&getApWclfInfo&getApPklotInfo&getApAtchPklotInfo&getApExposPubuseAreaInfo&getApHoExposPubuseAreaInfo&getApJijiguInfo&getApRoadRgstInfo&getApPlatPlcInfo&getApHsTpInfo"
inputFile = inputFile.split('&')
inputDataType = "xml"
inputInbound = 'https://github.com/joes5370/BJCode/raw/master/allCode.csv'
totalCountList = []

# inputFile변수는 필요한 모든 Operater들을 &기호로 분류하여 Google docs에 입력하였기 때문에 정제를 위해 split 함수로 쪼개준다.
# 최종적으로 inputFile 이라는 변수는 List형태로 저장됨
print(inputFile)
# Out:
# ['getApBasisOulnInfo', 'getApDongOulnInfo', 'getApFlrOulnInfo', 'getApHoOulnInfo', 'getApImprprInfo', 'getApHdcrMgmRgstInfo', 'getApDemolExtngMgmRgstInfo', 'getApTmpBldInfo', 'getApWclfInfo', 'getApPklotInfo', 'getApAtchPklotInfo', 'getApExposPubuseAreaInfo', 'getApHoExposPubuseAreaInfo', 'getApJijiguInfo', 'getApRoadRgstInfo', 'getApPlatPlcInfo', 'getApHsTpInfo']

# %% [markdown]
# #### 　　　　　03-4. 데이터 정제에 필요한 파일 불러오기

# %%
autoDownSource(inputInbound)

# 참고문헌에서 참조하라고 했던 문서(우리조의 경우 사이트에서 내려받고 csv파일형태로 새로 저장하여주었음)을 데이터프레임화 하기
codeDF = pd.read_csv('../data/inbound/allCode2.csv', encoding='ms949')

# 데이터프레임화 후 '법정동코드'칼럼의 데이터를 추출하여 codeList라는 변수에 List형태로 저장한다.
codeList = codeDF['법정동코드'].astype(str).tolist()
# Out:
# 100% [..........................................................................] 2085718 / 2085718

# %%
for i in inputFile:
    print('start ' + i)
    print()
    DF = pd.DataFrame()
    for j in codeList:
        sigunguCd = j[:5]
        bjdongCd = j[5:]

        url = makeURL(inputUrl, i, inputKey, sigunguCd, bjdongCd)

    ## 각 법정동코드마다 아이템 갯수와 페이지 수 확인
        response = requests.get(url)
        isCountChecked = False
    ## 같은 법정동코드는 같은 아이템 갯수와 페이지 수를 가지고 있으므로
    ## 한 번만 확인하면 됨
        # Check if page is up
        if (response.status_code == 200) & (isCountChecked == False):
        # Convert webpage to %Data
            Data = BeautifulSoup(response.text, 'lxml-xml')
            ## 불러온 xml 문서를 문자열로 변환
            DataToText = str(Data)
            target = 'totalCount'
            ## xml에 'totalCount' 태그가 있으면 확인함
            if target in DataToText:
                Data_totalCount = Data.find(target)
                totalCount = int(Data_totalCount.text)

                totalCountList.append(totalCount)


                ## 한 페이지에 아이템이 10개씩 있으므로 아이템 갯수를 10으로 나눈 몫이 페이지 수
                totalPage = math.ceil(totalCount / 10)
                isCountChecked = True
                print('totalPage is ' + str(totalPage))
                print()

            tmp = pd.DataFrame()
            for k in range(1, totalPage + 1):
                url_page = url + '&pageNo=' + str(k)
                print('url is ' + url_page)
                print()
                try:
                    tempDF = xmlProcess(url_page)
                    tmp = pd.concat([tmp, tempDF], sort = False)
                except Exception as e:
                    print(url + ' is excepted.')
                    print()
                print()
                print(str(k) + ' page is completed.')
                print()
            DF = pd.concat([DF, tmp], sort = False)

    resultName = outPath + inputFolder + '/' + i + '.csv'
    DF.to_csv(resultName, encoding = 'ms949', index = False)
    print(i + ' is completed ><')
table = pd.DataFrame[codeDF['법정동명'].tolist(), totalCountList]
table.columns = ['법정동명', '인허가 수']
# Out:
# start getApBasisOulnInfo
#
# totalPage is 23
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=1
#
#
# 1 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=2
#
#
# 2 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=3
#
#
# 3 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=4
#
#
# 4 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=5
#
#
# 5 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=6
#
#
# 6 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=7
#
#
# 7 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=8
#
#
# 8 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=9
#
#
# 9 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=10
#
#
# 10 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=11
#
#
# 11 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=12
#
#
# 12 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=13
#
#
# 13 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=14
#
#
# 14 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=15
#
#
# 15 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=16
#
#
# 16 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=17
#
#
# 17 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=18
#
#
# 18 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=19
#
#
# 19 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=20
#
#
# 20 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=21
#
#
# 21 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=22
#
#
# 22 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=23
#
#
# 23 page is completed.
#
# totalPage is 9
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=1
#
#
# 1 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=2
#
#
# 2 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=3
#
#
# 3 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=4
#
#
# 4 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=5
#
#
# 5 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=6
#
#
# 6 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=7
#
#
# 7 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=8
#
#
# 8 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApBasisOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=9
#
#
# 9 page is completed.
#
# getApBasisOulnInfo is completed ><
# start getApDongOulnInfo
#
# totalPage is 20
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=1
# 1 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=2
#
#
# 2 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=3
#
#
# 3 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=4
#
#
# 4 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=5
#
#
# 5 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=6
#
#
# 6 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=7
#
#
# 7 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=8
#
#
# 8 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=9
#
#
# 9 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=10
#
#
# 10 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=11
#
#
# 11 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=12
#
#
# 12 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=13
#
#
# 13 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=14
#
#
# 14 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=15
#
#
# 15 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=16
#
#
# 16 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=17
#
#
# 17 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=18
#
#
# 18 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=19
#
#
# 19 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=20
#
#
# 20 page is completed.
#
# totalPage is 8
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=1
#
#
# 1 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=2
#
#
# 2 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=3
#
#
# 3 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=4
#
#
# 4 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=5
#
#
# 5 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=6
#
#
# 6 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=7
#
#
# 7 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDongOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=8
#
#
# 8 page is completed.
#
# getApDongOulnInfo is completed ><
# start getApFlrOulnInfo
#
# totalPage is 64
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=1
#
#
# 1 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=2
#
#
# 2 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=3
#
#
# 3 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=4
#
#
# 4 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=5
#
#
# 5 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=6
#
#
# 6 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=7
#
#
# 7 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=8
# 8 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=9
#
#
# 9 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=10
#
#
# 10 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=11
#
#
# 11 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=12
#
#
# 12 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=13
#
#
# 13 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=14
#
#
# 14 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=15
#
#
# 15 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=16
#
#
# 16 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=17
#
#
# 17 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=18
#
#
# 18 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=19
#
#
# 19 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=20
#
#
# 20 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=21
#
#
# 21 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=22
#
#
# 22 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=23
#
#
# 23 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=24
#
#
# 24 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=25
#
#
# 25 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=26
#
#
# 26 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=27
#
#
# 27 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=28
#
#
# 28 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=29
#
#
# 29 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=30
#
#
# 30 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=31
#
#
# 31 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=32
#
#
# 32 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=33
#
#
# 33 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=34
#
#
# 34 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=35
#
#
# 35 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=36
#
#
# 36 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=37
#
#
# 37 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=38
#
#
# 38 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=39
#
#
# 39 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=40
#
#
# 40 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=41
#
#
# 41 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=42
# 42 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=43
#
#
# 43 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=44
#
#
# 44 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=45
#
#
# 45 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=46
#
#
# 46 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=47
#
#
# 47 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=48
#
#
# 48 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=49
#
#
# 49 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=50
#
#
# 50 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=51
#
#
# 51 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=52
#
#
# 52 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=53
#
#
# 53 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=54
#
#
# 54 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=55
#
#
# 55 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=56
#
#
# 56 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=57
#
#
# 57 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=58
#
#
# 58 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=59
#
#
# 59 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=60
#
#
# 60 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=61
#
#
# 61 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=62
#
#
# 62 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=63
#
#
# 63 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=64
#
#
# 64 page is completed.
#
# totalPage is 25
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=1
#
#
# 1 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=2
#
#
# 2 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=3
#
#
# 3 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=4
#
#
# 4 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=5
#
#
# 5 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=6
#
#
# 6 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=7
#
#
# 7 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=8
#
#
# 8 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=9
#
#
# 9 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=10
#
#
# 10 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=11
#
#
# 11 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=12
#
#
# 12 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=13
# 13 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=14
#
#
# 14 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=15
#
#
# 15 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=16
#
#
# 16 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=17
#
#
# 17 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=18
#
#
# 18 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=19
#
#
# 19 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=20
#
#
# 20 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=21
#
#
# 21 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=22
#
#
# 22 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=23
#
#
# 23 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=24
#
#
# 24 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApFlrOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=25
#
#
# 25 page is completed.
#
# getApFlrOulnInfo is completed ><
# start getApHoOulnInfo
#
# totalPage is 18
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=1
#
#
# 1 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=2
#
#
# 2 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=3
#
#
# 3 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=4
#
#
# 4 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=5
#
#
# 5 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=6
#
#
# 6 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=7
#
#
# 7 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=8
#
#
# 8 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=9
#
#
# 9 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=10
#
#
# 10 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=11
#
#
# 11 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=12
#
#
# 12 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=13
#
#
# 13 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=14
#
#
# 14 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=15
#
#
# 15 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=16
#
#
# 16 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=17
#
#
# 17 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=18
#
#
# 18 page is completed.
#
# totalPage is 11
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=1
#
#
# 1 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=2
#
#
# 2 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=3
#
#
# 3 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=4
#
#
# 4 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=5
# 5 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=6
#
#
# 6 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=7
#
#
# 7 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=8
#
#
# 8 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=9
#
#
# 9 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=10
#
#
# 10 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHoOulnInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=11
#
#
# 11 page is completed.
#
# getApHoOulnInfo is completed ><
# start getApImprprInfo
#
# totalPage is 1
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApImprprInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=1
#
#
# 1 page is completed.
#
# totalPage is 2
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApImprprInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=1
#
#
# 1 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApImprprInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=2
#
#
# 2 page is completed.
#
# getApImprprInfo is completed ><
# start getApHdcrMgmRgstInfo
#
# totalPage is 1
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApHdcrMgmRgstInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=1
#
#
# 1 page is completed.
#
# totalPage is 0
#
# getApHdcrMgmRgstInfo is completed ><
# start getApDemolExtngMgmRgstInfo
#
# totalPage is 8
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDemolExtngMgmRgstInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=1
#
#
# 1 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDemolExtngMgmRgstInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=2
#
#
# 2 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDemolExtngMgmRgstInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=3
#
#
# 3 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDemolExtngMgmRgstInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=4
#
#
# 4 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDemolExtngMgmRgstInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=5
#
#
# 5 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDemolExtngMgmRgstInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=6
#
#
# 6 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDemolExtngMgmRgstInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=7
#
#
# 7 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDemolExtngMgmRgstInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=8
#
#
# 8 page is completed.
#
# totalPage is 3
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDemolExtngMgmRgstInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=1
#
#
# 1 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApDemolExtngMgmRgstInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=2
#
#
# 2 page is completed.
#
# ...
#
#
# 6 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApJijiguInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=7
#
#
# 7 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApJijiguInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=8
#
#
# 8 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApJijiguInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=9
#
#
# 9 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApJijiguInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=10
#
#
# 10 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApJijiguInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=11
#
#
# 11 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApJijiguInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=12
#
#
# 12 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApJijiguInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=13
#
#
# 13 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApJijiguInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=14
#
#
# 14 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApJijiguInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=15
#
#
# 15 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApJijiguInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=16
#
#
# 16 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApJijiguInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=17
#
#
# 17 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApJijiguInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=18
#
#
# 18 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApJijiguInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=19
#
#
# 19 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApJijiguInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=20
#
#
# 20 page is completed.
#
# getApJijiguInfo is completed ><
# start getApRoadRgstInfo
#
# totalPage is 1
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApRoadRgstInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=1
#
#
# 1 page is completed.
#
# totalPage is 1
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApRoadRgstInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=1
#
#
# 1 page is completed.
# getApRoadRgstInfo is completed ><
# start getApPlatPlcInfo
#
# totalPage is 33
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=1
#
#
# 1 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=2
#
#
# 2 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=3
#
#
# 3 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=4
#
#
# 4 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=5
#
#
# 5 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=6
#
#
# 6 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=7
#
#
# 7 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=8
#
#
# 8 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=9
#
#
# 9 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=10
#
#
# 10 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=11
#
#
# 11 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=12
#
#
# 12 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=13
#
#
# 13 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=14
#
#
# 14 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=15
#
#
# 15 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=16
#
#
# 16 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=17
#
#
# 17 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=18
#
#
# 18 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=19
#
#
# 19 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=20
#
#
# 20 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=21
#
#
# 21 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=22
#
#
# 22 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=23
#
#
# 23 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=24
#
#
# 24 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=25
#
#
# 25 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=26
#
#
# 26 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=27
#
#
# 27 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=28
#
#
# 28 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=29
#
#
# 29 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=30
#
#
# 30 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=31
#
#
# 31 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=32
#
#
# 32 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10100&pageNo=33
#
#
# 33 page is completed.
#
# totalPage is 12
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=1
# 1 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=2
#
#
# 2 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=3
#
#
# 3 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=4
#
#
# 4 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=5
#
#
# 5 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=6
#
#
# 6 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=7
#
#
# 7 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=8
#
#
# 8 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=9
#
#
# 9 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=10
#
#
# 10 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=11
#
# http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200 is excepted.
#
#
# 11 page is completed.
#
# url is http://apis.data.go.kr/1611000/ArchPmsService/getApPlatPlcInfo?ServiceKey=ufe1cXhfaa3SBtlsFh402kse1ctLxx0%2BxZU0NDXcW6KST%2BIRc2HMgfJMC2%2BJ9vwZqCjCZvIyvusJfRZdESfOIA%3D%3D&sigunguCd=11110&bjdongCd=10200&pageNo=12
#
#
# 12 page is completed.
#
# getApPlatPlcInfo is completed ><
# start getApHsTpInfo
#
# totalPage is 0
#
# totalPage is 0
#
# getApHsTpInfo is completed ><
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-cfee548a6937> in <module>
#      54     DF.to_csv(resultName, encoding = 'ms949', index = False)
#      55     print(i + ' is completed ><')
# ---> 56 table = pd.DataFrame[codeDF['법정동명'].tolist(), totalCountList]
#      57 table.columns = ['법정동명', '인허가 수']
#
# TypeError: 'type' object is not subscriptable

# %%
dic = {'오퍼레이션':op, '법정동명':code}
op = []
bjdong = []
for i in inputFile:
    for j in codeDF.법정동명:
        op.append(i)
        bjdong.append(j)

dic = {'오퍼레이션':op, '법정동명':bjdong}
test = pd.DataFrame(dic)
test['인허가 수'] = totalCountList
test
# Out:
#                          오퍼레이션           법정동명  인허가 수
# 0           getApBasisOulnInfo  서울특별시 종로구 청운동    229
# 1           getApBasisOulnInfo  서울특별시 종로구 신교동     83
# 2            getApDongOulnInfo  서울특별시 종로구 청운동    195
# 3            getApDongOulnInfo  서울특별시 종로구 신교동     71
# 4             getApFlrOulnInfo  서울특별시 종로구 청운동    631
# 5             getApFlrOulnInfo  서울특별시 종로구 신교동    247
# 6              getApHoOulnInfo  서울특별시 종로구 청운동    171
# 7              getApHoOulnInfo  서울특별시 종로구 신교동    101
# 8              getApImprprInfo  서울특별시 종로구 청운동      7
# 9              getApImprprInfo  서울특별시 종로구 신교동     13
# 10        getApHdcrMgmRgstInfo  서울특별시 종로구 청운동      3
# 11        getApHdcrMgmRgstInfo  서울특별시 종로구 신교동      0
# 12  getApDemolExtngMgmRgstInfo  서울특별시 종로구 청운동     74
# 13  getApDemolExtngMgmRgstInfo  서울특별시 종로구 신교동     22
# 14             getApTmpBldInfo  서울특별시 종로구 청운동      8
# 15             getApTmpBldInfo  서울특별시 종로구 신교동      1
# 16               getApWclfInfo  서울특별시 종로구 청운동    138
# 17               getApWclfInfo  서울특별시 종로구 신교동     55
# 18              getApPklotInfo  서울특별시 종로구 청운동    114
# 19              getApPklotInfo  서울특별시 종로구 신교동     39
# 20          getApAtchPklotInfo  서울특별시 종로구 청운동      2
# 21          getApAtchPklotInfo  서울특별시 종로구 신교동      1
# 22    getApExposPubuseAreaInfo  서울특별시 종로구 청운동    340
# 23    getApExposPubuseAreaInfo  서울특별시 종로구 신교동    116
# 24  getApHoExposPubuseAreaInfo  서울특별시 종로구 청운동    403
# 25  getApHoExposPubuseAreaInfo  서울특별시 종로구 신교동    223
# 26             getApJijiguInfo  서울특별시 종로구 청운동    387
# 27             getApJijiguInfo  서울특별시 종로구 신교동    192
# 28           getApRoadRgstInfo  서울특별시 종로구 청운동      6
# 29           getApRoadRgstInfo  서울특별시 종로구 신교동      2
# 30            getApPlatPlcInfo  서울특별시 종로구 청운동    323
# 31            getApPlatPlcInfo  서울특별시 종로구 신교동    111
# 32               getApHsTpInfo  서울특별시 종로구 청운동      0
# 33               getApHsTpInfo  서울특별시 종로구 신교동      0

# %%
createFolder(outPath + inputFolder + "/시각화/")
for i in codeDF.법정동명:
    x = test[test.법정동명 == str(i)]
    x.to_csv(outPath + inputFolder + "/시각화/" + i + '.csv', index = False)

# %%
test2 = test[test.법정동명 == '서울특별시 종로구 신교동']
test2
# Out:
#                          오퍼레이션           법정동명  인허가 수
# 1           getApBasisOulnInfo  서울특별시 종로구 신교동     83
# 3            getApDongOulnInfo  서울특별시 종로구 신교동     71
# 5             getApFlrOulnInfo  서울특별시 종로구 신교동    247
# 7              getApHoOulnInfo  서울특별시 종로구 신교동    101
# 9              getApImprprInfo  서울특별시 종로구 신교동     13
# 11        getApHdcrMgmRgstInfo  서울특별시 종로구 신교동      0
# 13  getApDemolExtngMgmRgstInfo  서울특별시 종로구 신교동     22
# 15             getApTmpBldInfo  서울특별시 종로구 신교동      1
# 17               getApWclfInfo  서울특별시 종로구 신교동     55
# 19              getApPklotInfo  서울특별시 종로구 신교동     39
# 21          getApAtchPklotInfo  서울특별시 종로구 신교동      1
# 23    getApExposPubuseAreaInfo  서울특별시 종로구 신교동    116
# 25  getApHoExposPubuseAreaInfo  서울특별시 종로구 신교동    223
# 27             getApJijiguInfo  서울특별시 종로구 신교동    192
# 29           getApRoadRgstInfo  서울특별시 종로구 신교동      2
# 31            getApPlatPlcInfo  서울특별시 종로구 신교동    111
# 33               getApHsTpInfo  서울특별시 종로구 신교동      0
